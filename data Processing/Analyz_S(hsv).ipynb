# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data_folder = 'Data files'
input_file = f'{data_folder}/P_value_2023-06-14_04-46-27_Saturation.csv'

df_S = pd.read_csv(input_file)
df_S
# Out:
#        Frame    Sensor_1    Sensor_2    Sensor_3    Sensor_4    Sensor_5
# 0          0  140.405303  143.701818  156.330435  158.398333  163.345000  \
# 1          1  142.208333  142.520000  155.504348  157.725000  163.515000
# 2          2  141.950758  142.650909  156.398261  158.378333  163.876667
# 3          3  141.602273  142.709091  157.213913  159.211667  162.850000
# 4          4  141.520833  143.863636  157.120000  158.118333  163.203333
# ...      ...         ...         ...         ...         ...         ...
# 28350  28350  141.174242  141.727273  154.886957  156.821667  162.128333
# 28351  28351  141.373106  143.185455  155.753043  156.470000  162.476667
# 28352  28352  141.632576  144.436364  156.664348  157.350000  162.646667
# 28353  28353  141.473485  143.090909  155.667826  157.436667  162.890000
# 28354  28354  141.306818  143.496364  155.332174  157.368333  162.145000
#
#        Sensor_6    Sensor_7    Sensor_8    Sensor_9  ...  Sensor_63
# 0      156.5776  153.635802  142.717143  135.956439  ...   193.1872  \
# 1      156.7168  153.620370  142.342857  135.954545  ...   192.2832
# 2      156.8480  154.250000  142.758571  135.875000  ...   193.1680
# 3      156.5088  153.631173  142.751429  135.215909  ...   193.7984
# 4      156.1712  154.287037  142.198571  135.920455  ...   193.7488
# ...         ...         ...         ...         ...  ...        ...
# 28350  156.0448  153.455247  143.221429  135.808712  ...   191.8080
# 28351  156.0752  154.530864  143.891429  137.187500  ...   192.3744
# 28352  156.8816  154.890432  142.000000  136.526515  ...   193.4064
# 28353  157.7600  154.648148  143.194286  136.100379  ...   193.6432
# 28354  156.9968  154.384259  141.810000  136.437500  ...   193.7104
#
#        Sensor_64   Sensor_65   Sensor_66   Sensor_67  Sensor_68   Sensor_69
# 0       145.6464  114.165242  157.444444  205.378462   204.6080  197.398519  \
# 1       145.6096  114.314815  157.169516  205.324615   203.9552  196.352593
# 2       145.4416  114.331909  157.507123  205.236923   204.6992  196.989630
# 3       146.4992  113.955840  158.022792  205.253846   204.8160  197.115556
# 4       145.5680  113.784900  158.038462  206.150769   204.8368  196.250370
# ...          ...         ...         ...         ...        ...         ...
# 28350   144.9840  113.623932  156.004274  205.304615   204.6352  196.734815
# 28351   144.6512  114.340456  157.943020  205.906154   204.6912  196.179259
# 28352   146.0608  114.002849  157.495726  205.667692   204.8960  196.425185
# 28353   147.0272  113.998575  157.935897  206.043077   204.9328  197.383704
# 28354   146.1584  114.142450  158.126781  205.678462   204.8112  196.478519
#
#        Sensor_70   Sensor_71  Sensor_72
# 0       189.7696  177.427692   150.8624
# 1       189.2096  176.720000   149.5488
# 2       190.0592  176.432308   149.7552
# 3       189.2560  176.715385   149.5408
# 4       189.6640  176.476923   149.7200
# ...          ...         ...        ...
# 28350   188.9152  176.013846   150.3408
# 28351   189.6384  176.284615   151.0288
# 28352   189.4976  177.693846   150.7488
# 28353   189.3488  177.412308   151.0768
# 28354   189.7648  175.932308   150.9760
#
# [28355 rows x 73 columns]

# %%
# Get the column names excluding the frame column
sensor_columns = df_S.columns[1:]

# Determine the number of subplots needed
num_subplots = len(sensor_columns)

# Set the layout of the subplots
subplot_rows = int((num_subplots + 2) / 3)  # Adjust the number of rows as needed
subplot_cols = min(3, num_subplots)  # Adjust the number of columns as needed

# Create subplots
fig, axes = plt.subplots(subplot_rows, subplot_cols, figsize=(12, 4 * subplot_rows))  # Adjust the figure size as needed

# Flatten the axes array if necessary
axes = axes.flatten()

# Plot the pixel variation for each sensor
for i, sensor in enumerate(sensor_columns):
    ax = axes[i] if num_subplots > 1 else axes
    ax.plot(df_S['Frame'], df_S[sensor])
    ax.set_title(sensor, color='red')
    ax.set_xlabel('Frame')
    ax.set_ylabel('Pixel Variation', color='blue')
    ax.margins(x=0.05)  # Add some margin to the x-axis

# Adjust the spacing between subplots
fig.tight_layout(pad=2.0)  # Increase the padding between subplots

# Show the plot
plt.show()

# %% [markdown]
# ### \Delta%R : Variation of reflectivity

# %%
data_folder = 'Data files'
input_file = f'{data_folder}/Delta%R_S.csv'

df_standard = pd.read_csv(input_file)

# %%
# Get the column names excluding the frame column
sensor_columns = df_standard.columns[1:]

# Determine the number of subplots needed
num_subplots = len(sensor_columns)

# Set the layout of the subplots
subplot_rows = int((num_subplots + 2) / 3)  # Adjust the number of rows as needed
subplot_cols = min(3, num_subplots)  # Adjust the number of columns as needed

# Create subplots
fig, axes = plt.subplots(subplot_rows, subplot_cols, figsize=(12, 4 * subplot_rows))  # Adjust the figure size as needed

# Flatten the axes array if necessary
axes = axes.flatten()

# Apply moving average and plot the smoothed data
window_size = 1000  # Adjust the window size as desired
for i, sensor in enumerate(sensor_columns):
    ax = axes[i] if num_subplots > 1 else axes
    smoothed_data = df_standard[sensor].rolling(window=window_size, min_periods=1).mean()
    ax.plot(df_standard['Frame'][window_size - 1:], smoothed_data[window_size - 1:])  # Exclude the first (window_size - 1) points
    std_value = np.std(df_standard[sensor].rolling(window=window_size, min_periods=1).mean().iloc[window_size - 1:].values)
    ax.set_title(f"{sensor} (Std: {std_value:.4f})", color='red')
    ax.set_xlabel('Frame')
    ax.set_ylabel('Pixel Variation', color='blue')
    ax.margins(x=0.05)  # Add some margin to the x-axis


# Adjust the spacing between subplots
fig.tight_layout(pad=2.0)  # Increase the padding between subplots

# Show the plot
plt.show()
